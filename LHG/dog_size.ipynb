# %%
import numpy as np
import pandas as pd


import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import torchmetrics.functional as metrics



from torch.utils.data import DataLoader, Subset, WeightedRandomSampler
from torchvision.datasets import ImageFolder
from torchvision.models import vgg11, vgg16, VGG11_Weights, VGG16_Weights
from sklearn.model_selection import train_test_split
from typing import List, Dict, Union



from torchinfo import summary

# %%
class Custom_VGG(nn.Module):
    def __init__(
        self,
        features: nn.Module,
        nclasses: int = 3,
        init_weights: bool = True,
        dropout: float = 0.5,
    ) -> None:
        super().__init__()
        self.features = features
        self.avgpool = nn.AdaptiveAvgPool2d((7, 7))
        self.classifier = nn.Sequential(
            nn.Linear(512 * 7 * 7, 2048),
            nn.ReLU(True),
            nn.Dropout(dropout),
            nn.Linear(2048, 128),
            nn.ReLU(True),
            nn.Dropout(dropout),
            nn.Linear(128, nclasses),
        )
        if init_weights:
            for m in self.modules():
                if isinstance(m, nn.Conv2d):
                    nn.init.kaiming_normal_(
                        m.weight, mode="fan_out", nonlinearity="relu"
                    )
                    if m.bias is not None:
                        nn.init.constant_(m.bias, 0)
                elif isinstance(m, nn.BatchNorm2d):
                    nn.init.constant_(m.weight, 1)
                    nn.init.constant_(m.bias, 0)
                elif isinstance(m, nn.Linear):
                    nn.init.normal_(m.weight, 0, 0.01)
                    nn.init.constant_(m.bias, 0)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %%
# fmt: off
cfgs: Dict[str, List[Union[str, int]]] = {
    "VGG6" : [64, "M", 128, "M", 256, "M", 512, "M"],
    "VGG7" : [64, "M", 128, "M", 256, "M", 512, "M", 512, "M"],
    "VGG11": [64, "M", 128, "M", 256, 256, "M", 512, 512, "M", 512, 512, "M"],
    "VGG13": [64, 64, "M", 128, 128, "M", 256, 256, "M", 512, 512, "M", 512, 512, "M"],
    "VGG16": [64, 64, "M", 128, 128, "M", 256, 256, 256, "M", 512, 512, 512, "M", 512, 512, 512, "M"],
    "VGG19": [64, 64, "M", 128, 128, "M", 256, 256, 256, 256, "M", 512, 512, 512, 512, "M", 512, 512, 512, 512, "M"],
}
# fmt: on

# %%
def make_layers(cfg: List[Union[str, int]], batch_norm: bool = False) -> nn.Sequential:
    layers: List[nn.Module] = []
    in_channels = 3
    for v in cfg:
        if v == "M":
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
        else:
            v = int(v)
            conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=1)
            if batch_norm:
                layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
            else:
                layers += [conv2d, nn.ReLU(inplace=True)]
            in_channels = v
    return nn.Sequential(*layers)

# %%
def make_weights(labels: pd.DataFrame, nclasses: int):
    labels = labels.values
    weight_list = []

    for cls in range(nclasses):
        idx = np.where(labels == cls)[0]
        count = len(idx)
        weight = 1 / count
        weights = [weight] * count
        weight_list += weights

    return weight_list

# %%
def make_DataLoader(size: int = 256, batch_size: int = 64, view: bool = False):
    crop_size = 224 if size == 256 else 112
    preprocessing = transforms.Compose(
        [
            transforms.Resize(
                size, interpolation=transforms.InterpolationMode.BILINEAR
            ),
            transforms.CenterCrop(crop_size),
            transforms.ToTensor(),
            transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
        ]
    )

    file_root = "../DATA"
    dogDS = ImageFolder(root=file_root, transform=preprocessing)

    if view:
        print(dogDS.classes, len(dogDS.targets), len(dogDS.imgs), sep="\n")

    imgDF = pd.DataFrame(dogDS.imgs, columns=["image", "label"])
    imageDF = imgDF[["image"]]
    labelSR = imgDF.label

    X_train, X_valid, y_train, y_valid = train_test_split(
        imageDF, labelSR, test_size=0.1, random_state=42, stratify=labelSR
    )

    if view:
        print(X_train.shape, X_valid.shape, y_train.shape, y_valid.shape, sep="\n")

    train_idx = X_train.index.to_list()
    valid_idx = X_valid.index.to_list()

    trainDS = Subset(dogDS, train_idx)
    validDS = Subset(dogDS, valid_idx)

    if view:
        print(len(trainDS.dataset.targets), len(validDS.dataset.targets))

    train_weights = make_weights(y_train, len(y_train.unique()))
    train_weights = torch.DoubleTensor(train_weights)
    valid_weights = make_weights(y_valid, len(y_valid.unique()))
    valid_weights = torch.DoubleTensor(valid_weights)

    train_sampler = WeightedRandomSampler(train_weights, len(train_weights))
    valid_sampler = WeightedRandomSampler(valid_weights, len(valid_weights))

    trainDL = DataLoader(
        trainDS, batch_size=batch_size, sampler=train_sampler, drop_last=True
    )
    validDL = DataLoader(
        validDS, batch_size=batch_size, sampler=valid_sampler, drop_last=True
    )

    if view:
        for image, label in trainDL:
            print(image.shape, label.shape)
            pltsize = 1
            plt.figure(figsize=(10 * pltsize, pltsize))
            for i in range(10):
                plt.subplot(1, 10, i + 1)
                plt.axis("off")
                plt.imshow(np.transpose(image[i], (1, 2, 0)))
                plt.title("Class: " + str(label[i].item()))
            plt.show()
            break

    return trainDL, validDL, len(dogDS.classes)

# %%
trainDL, validDL, OUT = make_DataLoader(128, 64, True)
# Out:
# ['BIG', 'MID', 'SMALL']
# 20283
# 20283
# (18254, 1)
# (2029, 1)
# (18254,)
# (2029,)
# 20283 20283
# torch.Size([64, 3, 112, 112]) torch.Size([64])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
if torch.cuda.is_available():
    DEVICE = torch.device("cuda")
else:
    DEVICE = torch.device("cpu")

print("DEVICE :", DEVICE)
# Out:
# DEVICE : cpu

# %%
MODEL = Custom_VGG(
    features=make_layers(cfgs["VGG6"], batch_norm=True), nclasses=OUT
).to(DEVICE)


OPTIMIZER = optim.Adam(MODEL.parameters())


LOSS_FN = nn.CrossEntropyLoss()

# %%
summary(MODEL, input_size=(64, 3, 112, 112))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Custom_VGG                               [64, 3]                   --
# ├─Sequential: 1-1                        [64, 512, 7, 7]           --
# │    └─Conv2d: 2-1                       [64, 64, 112, 112]        1,792
# │    └─BatchNorm2d: 2-2                  [64, 64, 112, 112]        128
# │    └─ReLU: 2-3                         [64, 64, 112, 112]        --
# │    └─MaxPool2d: 2-4                    [64, 64, 56, 56]          --
# │    └─Conv2d: 2-5                       [64, 128, 56, 56]         73,856
# │    └─BatchNorm2d: 2-6                  [64, 128, 56, 56]         256
# │    └─ReLU: 2-7                         [64, 128, 56, 56]         --
# │    └─MaxPool2d: 2-8                    [64, 128, 28, 28]         --
# │    └─Conv2d: 2-9                       [64, 256, 28, 28]         295,168
# │    └─BatchNorm2d: 2-10                 [64, 256, 28, 28]         512
# │    └─ReLU: 2-11                        [64, 256, 28, 28]         --
# │    └─MaxPool2d: 2-12                   [64, 256, 14, 14]         --
# │    └─Conv2d: 2-13                      [64, 512, 14, 14]         1,180,160
# │    └─BatchNorm2d: 2-14                 [64, 512, 14, 14]         1,024
# │    └─ReLU: 2-15                        [64, 512, 14, 14]         --
# │    └─MaxPool2d: 2-16                   [64, 512, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-2                 [64, 512, 7, 7]           --
# ├─Sequential: 1-3                        [64, 3]                   --
# │    └─Linear: 2-17                      [64, 2048]                51,382,272
# │    └─ReLU: 2-18                        [64, 2048]                --
# │    └─Dropout: 2-19                     [64, 2048]                --
# │    └─Linear: 2-20                      [64, 128]                 262,272
# │    └─ReLU: 2-21                        [64, 128]                 --
# │    └─Dropout: 2-22                     [64, 128]                 --
# │    └─Linear: 2-23                      [64, 3]                   387
# ==========================================================================================
# Total params: 53,197,827
# Trainable params: 53,197,827
# Non-trainable params: 0
# Total mult-adds (G): 49.18
# ==========================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 1542.52
# Params size (MB): 212.79
# Estimated Total Size (MB): 1764.95
# ==========================================================================================

# %%
def learning(epoch, model, loader, optimizer, scores, mode="train", log_interval=100):
    if mode == "train":
        model.train()
        is_train = True
    elif mode == "test":
        model.eval()
        is_train = False
    else:
        raise ValueError("Invalid mode:", mode)

    loss_value = 0
    correct = 0
    with torch.set_grad_enabled(is_train):
        for batch_idx, (image, label) in enumerate(loader):
            image = image.to(DEVICE)
            label = label.to(DEVICE)

            output = model(image)
            loss = LOSS_FN(output, label)
            loss_value += loss.item()
            prediction = output.max(1, keepdim=True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()

            if is_train:
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                if batch_idx % log_interval == 0:
                    print(
                        f"Train Epoch: {epoch} [{batch_idx}]\tTrain Loss: {loss.item():.6f}"
                    )
                scores.append(loss.item())

            if not is_train:
                scores.append(loss.item())

    loss_value /= len(loader.dataset)
    accuracy = 100.0 * correct / len(loader.dataset)
    return loss_value, accuracy

# %%
EPOCHS = 10
train_loss_batch = []
test_loss_batch = []
test_loss_epoch = []
test_acc_epoch = []
save_dir = "../model/"

for epoch in range(1, EPOCHS + 1):

    learning(
        epoch,
        MODEL,
        trainDL,
        OPTIMIZER,
        train_loss_batch,
        mode="train",
        log_interval=10,
    )
    test_loss, test_accuracy = learning(
        epoch, MODEL, validDL, OPTIMIZER, test_loss_batch, mode="test"
    )
    test_loss_epoch.append(test_loss)
    test_acc_epoch.append(test_accuracy)
    print(
        f"\n[EPOCH: {epoch}], \tTest Loss: {test_loss:.4f}, \tTest Accuracy: {test_accuracy:.2f} % \n"
    )

    path = save_dir + f"vgg6_{epoch}.pth"
    torch.save(MODEL, path)
# Out:
# Train Epoch: 1 [0]	Train Loss: 1.058630
# Train Epoch: 1 [10]	Train Loss: 1.073392
# Train Epoch: 1 [20]	Train Loss: 1.070294
# Train Epoch: 1 [30]	Train Loss: 1.080031
# Train Epoch: 1 [40]	Train Loss: 1.041101
# Train Epoch: 1 [50]	Train Loss: 1.056344
# Train Epoch: 1 [60]	Train Loss: 1.075887
# Train Epoch: 1 [70]	Train Loss: 1.024143
# Train Epoch: 1 [80]	Train Loss: 1.123187
# Train Epoch: 1 [90]	Train Loss: 1.041397
# Train Epoch: 1 [100]	Train Loss: 1.054201
# Train Epoch: 1 [110]	Train Loss: 1.070304
# Train Epoch: 1 [120]	Train Loss: 1.070153
# Train Epoch: 1 [130]	Train Loss: 1.022663
# Train Epoch: 1 [140]	Train Loss: 1.017284
# Train Epoch: 1 [150]	Train Loss: 1.050058
# Train Epoch: 1 [160]	Train Loss: 1.045809
# Train Epoch: 1 [170]	Train Loss: 1.038552
# Train Epoch: 1 [180]	Train Loss: 1.015596
# Train Epoch: 1 [190]	Train Loss: 1.033025
# Train Epoch: 1 [200]	Train Loss: 1.094285
# Train Epoch: 1 [210]	Train Loss: 1.088494
# Train Epoch: 1 [220]	Train Loss: 1.064669
# Train Epoch: 1 [230]	Train Loss: 0.974920
# Train Epoch: 1 [240]	Train Loss: 1.067762
# Train Epoch: 1 [250]	Train Loss: 1.043438
# Train Epoch: 1 [260]	Train Loss: 1.062885
# Train Epoch: 1 [270]	Train Loss: 1.032969
# Train Epoch: 1 [280]	Train Loss: 1.083216
#
# [EPOCH: 1], 	Test Loss: 0.0160, 	Test Accuracy: 45.24 %
#
# Train Epoch: 2 [0]	Train Loss: 1.043642
# Train Epoch: 2 [10]	Train Loss: 1.083047
# Train Epoch: 2 [20]	Train Loss: 1.059908
# Train Epoch: 2 [30]	Train Loss: 1.030514
# Train Epoch: 2 [40]	Train Loss: 1.065997
# Train Epoch: 2 [50]	Train Loss: 1.023717
# Train Epoch: 2 [60]	Train Loss: 1.017010
# Train Epoch: 2 [70]	Train Loss: 1.081800
# Train Epoch: 2 [80]	Train Loss: 1.020609
# Train Epoch: 2 [90]	Train Loss: 1.022787
# Train Epoch: 2 [100]	Train Loss: 1.070356
# Train Epoch: 2 [110]	Train Loss: 1.032858
# Train Epoch: 2 [120]	Train Loss: 1.108320
# Train Epoch: 2 [130]	Train Loss: 1.055912
# Train Epoch: 2 [140]	Train Loss: 1.103033
# Train Epoch: 2 [150]	Train Loss: 1.022554
# Train Epoch: 2 [160]	Train Loss: 1.046000
# Train Epoch: 2 [170]	Train Loss: 1.024095
# Train Epoch: 2 [180]	Train Loss: 1.063591
# Train Epoch: 2 [190]	Train Loss: 0.996802
# Train Epoch: 2 [200]	Train Loss: 1.048883
# Train Epoch: 2 [210]	Train Loss: 1.098913
# Train Epoch: 2 [220]	Train Loss: 1.048498
# Train Epoch: 2 [230]	Train Loss: 1.069132
# Train Epoch: 2 [240]	Train Loss: 0.978478
# Train Epoch: 2 [250]	Train Loss: 1.042102
# Train Epoch: 2 [260]	Train Loss: 1.094460
# Train Epoch: 2 [270]	Train Loss: 0.987914
# Train Epoch: 2 [280]	Train Loss: 1.066854
#
# [EPOCH: 2], 	Test Loss: 0.0160, 	Test Accuracy: 45.29 %
#
# Train Epoch: 3 [0]	Train Loss: 1.078236
# Train Epoch: 3 [10]	Train Loss: 1.080469
# Train Epoch: 3 [20]	Train Loss: 1.117602
# Train Epoch: 3 [30]	Train Loss: 1.083506
# Train Epoch: 3 [40]	Train Loss: 1.033429
# Train Epoch: 3 [50]	Train Loss: 1.080519
# Train Epoch: 3 [60]	Train Loss: 1.053663
# Train Epoch: 3 [70]	Train Loss: 1.070728
# Train Epoch: 3 [80]	Train Loss: 1.008997
# Train Epoch: 3 [90]	Train Loss: 1.082817
# Train Epoch: 3 [100]	Train Loss: 1.086101
# Train Epoch: 3 [110]	Train Loss: 1.051189
# Train Epoch: 3 [120]	Train Loss: 1.159774
# Train Epoch: 3 [130]	Train Loss: 1.106902
# Train Epoch: 3 [140]	Train Loss: 1.064903
# Train Epoch: 3 [150]	Train Loss: 1.062982
# Train Epoch: 3 [160]	Train Loss: 1.030274
# Train Epoch: 3 [170]	Train Loss: 1.089971
# Train Epoch: 3 [180]	Train Loss: 0.985091
# Train Epoch: 3 [190]	Train Loss: 0.999051
# Train Epoch: 3 [200]	Train Loss: 0.996574
# Train Epoch: 3 [210]	Train Loss: 1.039750
# Train Epoch: 3 [220]	Train Loss: 1.038391
# Train Epoch: 3 [230]	Train Loss: 0.985297
# Train Epoch: 3 [240]	Train Loss: 1.122688
# Train Epoch: 3 [250]	Train Loss: 1.070491
# Train Epoch: 3 [260]	Train Loss: 1.014939
# Train Epoch: 3 [270]	Train Loss: 1.072768
# Train Epoch: 3 [280]	Train Loss: 1.011713
#
# [EPOCH: 3], 	Test Loss: 0.0159, 	Test Accuracy: 45.84 %
#
# Train Epoch: 4 [0]	Train Loss: 1.017367
# Train Epoch: 4 [10]	Train Loss: 1.067138
# Train Epoch: 4 [20]	Train Loss: 1.065439
# Train Epoch: 4 [30]	Train Loss: 1.074613
# Train Epoch: 4 [40]	Train Loss: 1.040446
# Train Epoch: 4 [50]	Train Loss: 1.083658
# Train Epoch: 4 [60]	Train Loss: 1.181811
# Train Epoch: 4 [70]	Train Loss: 1.076920
# Train Epoch: 4 [80]	Train Loss: 1.123713
# Train Epoch: 4 [90]	Train Loss: 1.070057
# Train Epoch: 4 [100]	Train Loss: 1.041137
# Train Epoch: 4 [110]	Train Loss: 1.111580
# Train Epoch: 4 [120]	Train Loss: 1.055771
# Train Epoch: 4 [130]	Train Loss: 1.101149
# Train Epoch: 4 [140]	Train Loss: 1.077121
# Train Epoch: 4 [150]	Train Loss: 1.048825
# Train Epoch: 4 [160]	Train Loss: 1.035649
# Train Epoch: 4 [170]	Train Loss: 1.034843
# Train Epoch: 4 [180]	Train Loss: 1.065735
# Train Epoch: 4 [190]	Train Loss: 0.983001
# Train Epoch: 4 [200]	Train Loss: 1.078945
# Train Epoch: 4 [210]	Train Loss: 1.025177
# Train Epoch: 4 [220]	Train Loss: 1.028366
# Train Epoch: 4 [230]	Train Loss: 1.017399
# Train Epoch: 4 [240]	Train Loss: 1.084648
# Train Epoch: 4 [250]	Train Loss: 1.040620
# Train Epoch: 4 [260]	Train Loss: 1.109753
# Train Epoch: 4 [270]	Train Loss: 1.036575
# Train Epoch: 4 [280]	Train Loss: 0.991533
#
# [EPOCH: 4], 	Test Loss: 0.0160, 	Test Accuracy: 45.98 %
#
# Train Epoch: 5 [0]	Train Loss: 1.083904
# Train Epoch: 5 [10]	Train Loss: 1.049052
# Train Epoch: 5 [20]	Train Loss: 1.022156
# Train Epoch: 5 [30]	Train Loss: 1.091713
# Train Epoch: 5 [40]	Train Loss: 1.059884
# Train Epoch: 5 [50]	Train Loss: 1.093274
# Train Epoch: 5 [60]	Train Loss: 0.970415
# Train Epoch: 5 [70]	Train Loss: 0.998385
# Train Epoch: 5 [80]	Train Loss: 1.083282
# Train Epoch: 5 [90]	Train Loss: 1.064915
# Train Epoch: 5 [100]	Train Loss: 1.052923
# Train Epoch: 5 [110]	Train Loss: 1.002042
# Train Epoch: 5 [120]	Train Loss: 1.114068
# Train Epoch: 5 [130]	Train Loss: 1.065228
# Train Epoch: 5 [140]	Train Loss: 1.104047
# Train Epoch: 5 [150]	Train Loss: 1.039963
# Train Epoch: 5 [160]	Train Loss: 1.028723
# Train Epoch: 5 [170]	Train Loss: 1.060358
# Train Epoch: 5 [180]	Train Loss: 1.039174
# Train Epoch: 5 [190]	Train Loss: 0.943914
# Train Epoch: 5 [200]	Train Loss: 1.056429
# Train Epoch: 5 [210]	Train Loss: 1.092312
# Train Epoch: 5 [220]	Train Loss: 1.013588
# Train Epoch: 5 [230]	Train Loss: 1.008531
# Train Epoch: 5 [240]	Train Loss: 1.061834
# Train Epoch: 5 [250]	Train Loss: 1.074295
# Train Epoch: 5 [260]	Train Loss: 1.063869
# Train Epoch: 5 [270]	Train Loss: 1.035271
# Train Epoch: 5 [280]	Train Loss: 1.017639
#
# [EPOCH: 5], 	Test Loss: 0.0160, 	Test Accuracy: 45.64 %
#
# Train Epoch: 6 [0]	Train Loss: 0.988841
# Train Epoch: 6 [10]	Train Loss: 1.056380
# Train Epoch: 6 [20]	Train Loss: 1.099936
# Train Epoch: 6 [30]	Train Loss: 0.994136
# Train Epoch: 6 [40]	Train Loss: 1.033090
# Train Epoch: 6 [50]	Train Loss: 1.046841
# Train Epoch: 6 [60]	Train Loss: 1.012068
# Train Epoch: 6 [70]	Train Loss: 1.012310
# Train Epoch: 6 [80]	Train Loss: 1.012516
# Train Epoch: 6 [90]	Train Loss: 1.009351
# Train Epoch: 6 [100]	Train Loss: 1.066569
# Train Epoch: 6 [110]	Train Loss: 1.089650
# Train Epoch: 6 [120]	Train Loss: 1.046609
# Train Epoch: 6 [130]	Train Loss: 1.074610
# Train Epoch: 6 [140]	Train Loss: 1.046318
# Train Epoch: 6 [150]	Train Loss: 1.076519
# Train Epoch: 6 [160]	Train Loss: 1.060298
# Train Epoch: 6 [170]	Train Loss: 1.040687
# Train Epoch: 6 [180]	Train Loss: 1.054062
# Train Epoch: 6 [190]	Train Loss: 1.060525
# Train Epoch: 6 [200]	Train Loss: 1.058720
# Train Epoch: 6 [210]	Train Loss: 1.064288
# Train Epoch: 6 [220]	Train Loss: 1.089812
# Train Epoch: 6 [230]	Train Loss: 1.088871
# Train Epoch: 6 [240]	Train Loss: 1.016446
# Train Epoch: 6 [250]	Train Loss: 1.011030
# Train Epoch: 6 [260]	Train Loss: 1.096231
# Train Epoch: 6 [270]	Train Loss: 1.012795
# Train Epoch: 6 [280]	Train Loss: 1.121949
#
# [EPOCH: 6], 	Test Loss: 0.0178, 	Test Accuracy: 36.72 %
#
# Train Epoch: 7 [0]	Train Loss: 1.226830
# Train Epoch: 7 [10]	Train Loss: 1.080686
# Train Epoch: 7 [20]	Train Loss: 1.048673
# Train Epoch: 7 [30]	Train Loss: 1.002501
# Train Epoch: 7 [40]	Train Loss: 0.998253
# Train Epoch: 7 [50]	Train Loss: 0.987394
# Train Epoch: 7 [60]	Train Loss: 1.058314
# Train Epoch: 7 [70]	Train Loss: 1.076882
# Train Epoch: 7 [80]	Train Loss: 1.051397
# Train Epoch: 7 [90]	Train Loss: 1.038811
# Train Epoch: 7 [100]	Train Loss: 1.043439
# Train Epoch: 7 [110]	Train Loss: 1.021913
# Train Epoch: 7 [120]	Train Loss: 1.094428
# Train Epoch: 7 [130]	Train Loss: 1.037290
# Train Epoch: 7 [140]	Train Loss: 1.029520
# Train Epoch: 7 [150]	Train Loss: 1.062165
# Train Epoch: 7 [160]	Train Loss: 1.016049
# Train Epoch: 7 [170]	Train Loss: 1.092411
# Train Epoch: 7 [180]	Train Loss: 1.049225
# Train Epoch: 7 [190]	Train Loss: 1.035978
# Train Epoch: 7 [200]	Train Loss: 1.024350
# Train Epoch: 7 [210]	Train Loss: 1.019917
# Train Epoch: 7 [220]	Train Loss: 1.076431
# Train Epoch: 7 [230]	Train Loss: 1.042404
# Train Epoch: 7 [240]	Train Loss: 1.033559
# Train Epoch: 7 [250]	Train Loss: 0.995520
# Train Epoch: 7 [260]	Train Loss: 1.110721
# Train Epoch: 7 [270]	Train Loss: 1.013335
# Train Epoch: 7 [280]	Train Loss: 1.079585
#
# [EPOCH: 7], 	Test Loss: 0.0158, 	Test Accuracy: 46.38 %
#
# Train Epoch: 8 [0]	Train Loss: 1.012505
# Train Epoch: 8 [10]	Train Loss: 1.037604
# Train Epoch: 8 [20]	Train Loss: 1.038415
# Train Epoch: 8 [30]	Train Loss: 1.059784
# Train Epoch: 8 [40]	Train Loss: 1.114747
# Train Epoch: 8 [50]	Train Loss: 1.196908
# Train Epoch: 8 [60]	Train Loss: 1.069151
# Train Epoch: 8 [70]	Train Loss: 1.043163
# Train Epoch: 8 [80]	Train Loss: 1.037992
# Train Epoch: 8 [90]	Train Loss: 1.070541
# Train Epoch: 8 [100]	Train Loss: 0.978991
# Train Epoch: 8 [110]	Train Loss: 1.028875
# Train Epoch: 8 [120]	Train Loss: 1.066664
# Train Epoch: 8 [130]	Train Loss: 1.037734
# Train Epoch: 8 [140]	Train Loss: 1.014890
# Train Epoch: 8 [150]	Train Loss: 1.037958
# Train Epoch: 8 [160]	Train Loss: 1.040886
# Train Epoch: 8 [170]	Train Loss: 0.991693
# Train Epoch: 8 [180]	Train Loss: 1.029486
# Train Epoch: 8 [190]	Train Loss: 1.030419
# Train Epoch: 8 [200]	Train Loss: 1.008160
# Train Epoch: 8 [210]	Train Loss: 1.099748
# Train Epoch: 8 [220]	Train Loss: 1.078761
# Train Epoch: 8 [230]	Train Loss: 1.042729
# Train Epoch: 8 [240]	Train Loss: 0.977709
# Train Epoch: 8 [250]	Train Loss: 1.035767
# Train Epoch: 8 [260]	Train Loss: 1.055838
# Train Epoch: 8 [270]	Train Loss: 1.088892
# Train Epoch: 8 [280]	Train Loss: 1.052643
#
# [EPOCH: 8], 	Test Loss: 0.0158, 	Test Accuracy: 47.91 %
#
# Train Epoch: 9 [0]	Train Loss: 1.036008
# Train Epoch: 9 [10]	Train Loss: 1.079674
# Train Epoch: 9 [20]	Train Loss: 1.077116
# Train Epoch: 9 [30]	Train Loss: 1.057768
# Train Epoch: 9 [40]	Train Loss: 1.002852
# Train Epoch: 9 [50]	Train Loss: 1.074233
# Train Epoch: 9 [60]	Train Loss: 0.982361
# Train Epoch: 9 [70]	Train Loss: 1.108792
# Train Epoch: 9 [80]	Train Loss: 1.074930
# Train Epoch: 9 [90]	Train Loss: 1.123185
# Train Epoch: 9 [100]	Train Loss: 1.082082
# Train Epoch: 9 [110]	Train Loss: 1.065898
# Train Epoch: 9 [120]	Train Loss: 1.099615
# Train Epoch: 9 [130]	Train Loss: 1.076003
# Train Epoch: 9 [140]	Train Loss: 1.105618
# Train Epoch: 9 [150]	Train Loss: 0.992936
# Train Epoch: 9 [160]	Train Loss: 1.032550
# Train Epoch: 9 [170]	Train Loss: 1.041461
# Train Epoch: 9 [180]	Train Loss: 1.040902
# Train Epoch: 9 [190]	Train Loss: 1.039767
# Train Epoch: 9 [200]	Train Loss: 1.027956
# Train Epoch: 9 [210]	Train Loss: 1.042161
# Train Epoch: 9 [220]	Train Loss: 1.088259
# Train Epoch: 9 [230]	Train Loss: 1.004125
# Train Epoch: 9 [240]	Train Loss: 1.021409
# Train Epoch: 9 [250]	Train Loss: 1.070202
# Train Epoch: 9 [260]	Train Loss: 1.038522
# Train Epoch: 9 [270]	Train Loss: 1.064494
# Train Epoch: 9 [280]	Train Loss: 1.096451
#
# [EPOCH: 9], 	Test Loss: 0.0158, 	Test Accuracy: 45.44 %
#
# Train Epoch: 10 [0]	Train Loss: 1.037138
# Train Epoch: 10 [10]	Train Loss: 1.091507
# Train Epoch: 10 [20]	Train Loss: 0.997247
# Train Epoch: 10 [30]	Train Loss: 1.046585
# Train Epoch: 10 [40]	Train Loss: 1.000442
# Train Epoch: 10 [50]	Train Loss: 1.110566
# Train Epoch: 10 [60]	Train Loss: 1.027757
# Train Epoch: 10 [70]	Train Loss: 1.093640
# Train Epoch: 10 [80]	Train Loss: 1.076780
# Train Epoch: 10 [90]	Train Loss: 1.063343
# Train Epoch: 10 [100]	Train Loss: 0.981916
# Train Epoch: 10 [110]	Train Loss: 1.050765
# Train Epoch: 10 [120]	Train Loss: 1.008816
# Train Epoch: 10 [130]	Train Loss: 1.075459
# Train Epoch: 10 [140]	Train Loss: 1.040609
# Train Epoch: 10 [150]	Train Loss: 1.012644
# Train Epoch: 10 [160]	Train Loss: 1.082030
# Train Epoch: 10 [170]	Train Loss: 1.070748
# Train Epoch: 10 [180]	Train Loss: 1.086314
# Train Epoch: 10 [190]	Train Loss: 0.973062
# Train Epoch: 10 [200]	Train Loss: 1.054925
# Train Epoch: 10 [210]	Train Loss: 1.000289
# Train Epoch: 10 [220]	Train Loss: 1.002100
# Train Epoch: 10 [230]	Train Loss: 1.037415
# Train Epoch: 10 [240]	Train Loss: 1.010827
# Train Epoch: 10 [250]	Train Loss: 0.993226
# Train Epoch: 10 [260]	Train Loss: 1.099155
# Train Epoch: 10 [270]	Train Loss: 1.042024
# Train Epoch: 10 [280]	Train Loss: 1.108653
#
# [EPOCH: 10], 	Test Loss: 0.0159, 	Test Accuracy: 45.98 %

# %%
trainDL2, validDL2, OUT2 = make_DataLoader(256, 64, True)
# Out:
# ['BIG', 'MID', 'SMALL']
# 20283
# 20283
# (18254, 1)
# (2029, 1)
# (18254,)
# (2029,)
# 20283 20283
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([64, 3, 224, 224]) torch.Size([64])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
vgg_sequential = nn.Sequential(
    nn.Linear(512 * 7 * 7, 2048),
    nn.ReLU(True),
    nn.Dropout(0.5),
    nn.Linear(2048, out_features=256),
    nn.ReLU(True),
    nn.Dropout(0.5),
    nn.Linear(256, 3),
)

# %%
vgg_model = vgg11(weights=VGG11_Weights.DEFAULT)

vgg_model.classifier = vgg_sequential

# %%
summary(model=vgg_model, input_size=(64, 3, 224, 224))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VGG                                      [64, 3]                   --
# ├─Sequential: 1-1                        [64, 512, 7, 7]           --
# │    └─Conv2d: 2-1                       [64, 64, 224, 224]        1,792
# │    └─ReLU: 2-2                         [64, 64, 224, 224]        --
# │    └─MaxPool2d: 2-3                    [64, 64, 112, 112]        --
# │    └─Conv2d: 2-4                       [64, 128, 112, 112]       73,856
# │    └─ReLU: 2-5                         [64, 128, 112, 112]       --
# │    └─MaxPool2d: 2-6                    [64, 128, 56, 56]         --
# │    └─Conv2d: 2-7                       [64, 256, 56, 56]         295,168
# │    └─ReLU: 2-8                         [64, 256, 56, 56]         --
# │    └─Conv2d: 2-9                       [64, 256, 56, 56]         590,080
# │    └─ReLU: 2-10                        [64, 256, 56, 56]         --
# │    └─MaxPool2d: 2-11                   [64, 256, 28, 28]         --
# │    └─Conv2d: 2-12                      [64, 512, 28, 28]         1,180,160
# │    └─ReLU: 2-13                        [64, 512, 28, 28]         --
# │    └─Conv2d: 2-14                      [64, 512, 28, 28]         2,359,808
# │    └─ReLU: 2-15                        [64, 512, 28, 28]         --
# │    └─MaxPool2d: 2-16                   [64, 512, 14, 14]         --
# │    └─Conv2d: 2-17                      [64, 512, 14, 14]         2,359,808
# │    └─ReLU: 2-18                        [64, 512, 14, 14]         --
# │    └─Conv2d: 2-19                      [64, 512, 14, 14]         2,359,808
# │    └─ReLU: 2-20                        [64, 512, 14, 14]         --
# │    └─MaxPool2d: 2-21                   [64, 512, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-2                 [64, 512, 7, 7]           --
# ├─Sequential: 1-3                        [64, 3]                   --
# │    └─Linear: 2-22                      [64, 2048]                51,382,272
# │    └─ReLU: 2-23                        [64, 2048]                --
# │    └─Dropout: 2-24                     [64, 2048]                --
# │    └─Linear: 2-25                      [64, 256]                 524,544
# │    └─ReLU: 2-26                        [64, 256]                 --
# │    └─Dropout: 2-27                     [64, 256]                 --
# │    └─Linear: 2-28                      [64, 3]                   771
# ==========================================================================================
# Total params: 61,128,067
# Trainable params: 61,128,067
# Non-trainable params: 0
# Total mult-adds (G): 482.87
# ==========================================================================================
# Input size (MB): 38.54
# Forward/backward pass size (MB): 3803.32
# Params size (MB): 244.51
# Estimated Total Size (MB): 4086.37
# ==========================================================================================

# %%
for name, param in vgg_model.named_parameters():
    param.requires_grad = False

for name, param in vgg_model.classifier.named_parameters():
    param.requires_grad = True

# %%
EPOCHS = 10
train_loss_list = []
test_loss_list = []

for epoch in range(1, EPOCHS + 1):

    learning(
        epoch,
        vgg_model,
        trainDL2,
        OPTIMIZER,
        train_loss_list,
        mode="train",
        log_interval=10,
    )
    test_loss, test_accuracy = learning(
        epoch, vgg_model, validDL2, OPTIMIZER, test_loss_list, mode="test"
    )

    print(
        f"\n[EPOCH: {epoch}], \tTest Loss: {test_loss:.4f}, \tTest Accuracy: {test_accuracy:.2f} % \n"
    )
# Out:
# Train Epoch: 1 [0]	Train Loss: 1.095694
# Train Epoch: 1 [10]	Train Loss: 1.179971
# Train Epoch: 1 [20]	Train Loss: 1.121795
# Train Epoch: 1 [30]	Train Loss: 1.146362
# Train Epoch: 1 [40]	Train Loss: 1.156427
# Train Epoch: 1 [50]	Train Loss: 1.169556
# Train Epoch: 1 [60]	Train Loss: 1.144722
# Train Epoch: 1 [70]	Train Loss: 1.093064
# Train Epoch: 1 [80]	Train Loss: 1.112342
# Train Epoch: 1 [90]	Train Loss: 1.123363
# Train Epoch: 1 [100]	Train Loss: 1.059460
# Train Epoch: 1 [110]	Train Loss: 1.265285
# Train Epoch: 1 [120]	Train Loss: 1.073885
# Train Epoch: 1 [130]	Train Loss: 1.045716
# Train Epoch: 1 [140]	Train Loss: 1.152878
# Train Epoch: 1 [150]	Train Loss: 1.103603
# Train Epoch: 1 [160]	Train Loss: 1.095851
# Train Epoch: 1 [170]	Train Loss: 1.141881
# Train Epoch: 1 [180]	Train Loss: 1.152674
# Train Epoch: 1 [190]	Train Loss: 1.125738
# Train Epoch: 1 [200]	Train Loss: 1.080094
# Train Epoch: 1 [210]	Train Loss: 1.165286
# Train Epoch: 1 [220]	Train Loss: 1.101178
# Train Epoch: 1 [230]	Train Loss: 1.154997
# Train Epoch: 1 [240]	Train Loss: 1.161409
# Train Epoch: 1 [250]	Train Loss: 1.092409
# Train Epoch: 1 [260]	Train Loss: 1.109276
# Train Epoch: 1 [270]	Train Loss: 1.090610
# Train Epoch: 1 [280]	Train Loss: 1.141500
#
# [EPOCH: 1], 	Test Loss: 0.0166, 	Test Accuracy: 45.59 %
#
# Train Epoch: 2 [0]	Train Loss: 1.100314
# Train Epoch: 2 [10]	Train Loss: 1.126869
# Train Epoch: 2 [20]	Train Loss: 1.107244
# Train Epoch: 2 [30]	Train Loss: 1.126959
# Train Epoch: 2 [40]	Train Loss: 1.157609
# Train Epoch: 2 [50]	Train Loss: 1.128877
# Train Epoch: 2 [60]	Train Loss: 1.160440
# Train Epoch: 2 [70]	Train Loss: 1.176067
# Train Epoch: 2 [80]	Train Loss: 1.053991
# Train Epoch: 2 [90]	Train Loss: 1.145346
# Train Epoch: 2 [100]	Train Loss: 1.127080
# Train Epoch: 2 [110]	Train Loss: 1.191366
# Train Epoch: 2 [120]	Train Loss: 1.092323
# Train Epoch: 2 [130]	Train Loss: 1.108240
# Train Epoch: 2 [140]	Train Loss: 1.097199
# Train Epoch: 2 [150]	Train Loss: 1.077136
# Train Epoch: 2 [160]	Train Loss: 1.113739
# Train Epoch: 2 [170]	Train Loss: 1.097686
# Train Epoch: 2 [180]	Train Loss: 1.107578
# Train Epoch: 2 [190]	Train Loss: 1.107420
# Train Epoch: 2 [200]	Train Loss: 1.124305
# Train Epoch: 2 [210]	Train Loss: 1.122048
# Train Epoch: 2 [220]	Train Loss: 1.099878
# Train Epoch: 2 [230]	Train Loss: 1.088192
# Train Epoch: 2 [240]	Train Loss: 1.128730
# Train Epoch: 2 [250]	Train Loss: 1.105321
# Train Epoch: 2 [260]	Train Loss: 1.131397
# Train Epoch: 2 [270]	Train Loss: 1.105965
# Train Epoch: 2 [280]	Train Loss: 1.157056
